# %%
from __future__ import print_function
__author__ = "Federica B. Bianco, CUSP NYU 2016"

# %% [markdown]
# # Create a <i>reproducible research</i> chunk of code
#
# That means we want the reader to be able to reproduce every step of the work we do.
#
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the random draw gives the same number to the user that it gave to me? That is not random!
#
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a **uniform random distribution** or a number near 0 if we aks for a **Gaussian distribution with mean 0**. <i> But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn</i>.
#
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
#
# Fill in the empty cells below with code, as directed.

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %% [markdown]
# ## THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ### give numpy as seed for this code to be reproducible
# (no points if this is wrong)
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
# code here... 
np.random.seed(22)
rand_num1 = np.random.random()
print ("random number with seed 22: ", rand_num1)

np.random.seed(22)
rand_num2 = np.random.random()
print ("random number with seed 22: ", rand_num2)
# Out:
# random number with seed 22:  0.208460537359
# random number with seed 22:  0.208460537359

# %% [markdown]
# ### 1. Generate random distributions. use the function
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
# ### to generate 100 2-dimensional random datapoints in a gaussian distribution
#
# call the array ReprRand

# %%
# code here...
np.random.seed(22)
ReprRand = np.random.randn(2,100) # N(0,1) ~ 1*np.random.randn(100,2)+0
print (ReprRand)
# Out:
# [[ -9.19499199e-02  -1.46335065e+00   1.08179168e+00  -2.39325168e-01
#    -4.91129136e-01  -1.00227201e+00   9.18821503e-01  -1.10363210e+00
#     6.26493456e-01  -5.61513781e-01   2.88551183e-02  -2.30767188e-01
#     5.87752215e-01   7.52317579e-01  -1.05850255e+00   1.05597241e+00
#     7.47750266e-01   1.06467659e+00   1.52012959e+00  -1.48860294e+00
#     1.85998989e+00  -1.59861303e+00  -6.46073613e-01   3.37325002e-01
#     1.04672873e+00   6.29143340e-01   3.63059095e-01   5.55749697e-01
#    -1.08854953e+00   2.36947718e-02   2.49917664e+00  -2.49003039e+00
#    -2.34862387e-01  -9.75634596e-02  -8.86529342e-01  -1.36713238e-01
#     1.01978927e-01  -2.50929536e-01  -7.88123044e-02  -1.08516417e+00
#     5.94928451e-01  -6.38908072e-01  -1.10783686e+00   2.10614576e+00
#    -5.67387770e-01  -4.79949793e-01  -1.92322986e+00   3.99588542e-01
#    -1.04818387e+00  -6.93878703e-01   7.45339147e-01   5.36909995e-01
#    -7.32721777e-01   5.55715630e-01   4.32289301e-01  -1.35803978e-01
#    -9.41106092e-01   4.84767363e-01  -1.53282145e+00   4.04978890e-01
#     1.28261247e-02  -1.23171556e+00  -1.05308502e+00   2.51622182e+00
#    -2.03902850e+00   9.44873093e-02  -3.14823335e-01   4.90314717e-01
#     3.54976188e-01   9.50711346e-01   7.60371799e-01   1.15036262e-02
#    -1.37605696e+00  -2.71554684e-01   5.42252051e-01   5.35522208e-01
#     1.15999804e+00  -1.65005049e-01  -1.17940257e+00  -5.45298951e-01
#     2.70502670e-01   9.80237559e-01   1.00688840e+00   7.82156255e-01
#    -1.24859166e+00  -4.23833446e-01   5.52608154e-01   3.29603425e-01
#     8.63118290e-01  -1.22737803e+00   6.24874027e-01  -2.76953295e+00
#    -4.92177594e-01   6.91481980e-02  -3.50002572e-01   8.69345174e-01
#    -2.16764206e-01   1.71184947e-02   6.89713394e-01  -8.83143152e-01]
#  [  1.49724807e+00  -6.46544580e-01   6.04491248e-01   2.14950129e-01
#    -4.23600706e-01   1.04419171e-01   3.11572046e-01  -4.67063160e-01
#     2.20054897e+00  -1.01373789e+00   1.18337723e-03   1.12829287e+00
#     5.07971216e-01   1.07954080e+00  -1.53247466e+00  -2.34129538e-01
#     3.88585950e-02   1.25842316e+00  -8.21339274e-01  -5.54690377e-02
#     1.88000542e+00   3.83969645e-01   4.33214560e-01  -6.34958697e-02
#     1.18903123e+00  -1.87111280e+00  -8.15068674e-01  -5.65953290e-01
#     1.28137346e-01   2.99980992e-03  -2.13100489e+00   1.10942406e-01
#    -8.53231426e-01   2.82726171e+00  -2.71408373e-01   1.05881028e+00
#    -5.54835346e-01  -2.44950297e-01  -8.53094678e-01   8.48312535e-01
#     1.32561460e+00  -1.26540482e+00   5.17647928e-01   7.81605034e-01
#     1.38838387e+00  -4.72735950e-01   1.58810559e+00  -1.08659475e+00
#     3.59939299e-01  -3.29301228e-01  -1.34302326e-01   1.25612423e+00
#     6.96753523e-01   3.07539698e+00   8.88463666e-02  -5.81676787e-01
#     1.35208046e+00   4.22272055e-01  -2.77918227e-01   1.48686537e+00
#     1.63209071e+00  -1.31130411e+00  -2.07281639e-01   1.36391564e+00
#    -5.91848825e-01   1.87545843e+00   4.36575846e-02   5.96804394e-01
#     3.50396787e-01  -9.25649713e-01   1.03701184e-02  -5.31001944e-01
#    -2.48447206e-01   1.25946936e+00   8.38336667e-01  -6.19785607e-02
#     4.48828566e-01   1.69754775e+00   1.36768908e-01  -2.38795014e-01
#     9.05536997e-01  -4.02457797e-01  -1.07401861e+00   2.05472713e+00
#    -9.59473793e-01   3.20019649e-01   6.02291887e-01  -1.56811888e-01
#     2.07029619e+00   2.11495555e+00   5.92839575e-01  -1.38721570e+00
#     5.56130628e-01  -1.60457753e+00   7.32211911e-01   1.02076736e+00
#     4.83411147e-01   1.44245434e+00   3.49343235e-01  -7.81752992e-01]]

# %% [markdown]
# #### if you did this correctly the shape of ReprRand will be (2, 100)

# %%
# run this cell
print (ReprRand.shape)
# Out:
# (2, 100)

# %% [markdown]
# ## 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
# --Keep seed changing--
# Generate a different seed for each (2,100) numpy arrays  
ReprRandAll = np.zeros((50, 2, 100))
for i in range(50):
    np.random.seed(i+1)
    ReprRand = (1 + i*0.1) * np.random.randn(2,100) + i*0.1
    ReprRandAll[i][:][:] = ReprRand

print (ReprRandAll)
# Out:
# [[[  1.62434536  -0.61175641  -0.52817175 ...,   0.04359686  -0.62000084
#      0.69803203]
#   [ -0.44712856   1.2245077    0.40349164 ...,   0.4202822    0.81095167
#      1.04444209]]
#
#  [[ -0.35843363   0.03810649  -2.24981571 ...,  -0.1388488    1.39088465
#     -2.47796351]
#   [  1.37767364   0.52468585  -1.1464466  ...,   0.7084807    1.23633197
#     -0.26190268]]
#
#  [[  2.34635417   0.72381182   0.31579696 ...,  -0.8265246   -0.16024729
#      2.78977921]
#   [  1.24914287  -1.35224396   0.10431087 ...,   1.63407      0.08571488
#     -0.43262534]]
#
#  ...,
#  [[ -0.96369852  -1.36138459   1.06296728 ...,  -5.92755007   3.23337951
#      8.0777686 ]
#   [ -5.05702224  -0.54011706   1.59539409 ...,   6.99529193   6.34966658
#     10.7893427 ]]
#
#  [[ -1.25032265   0.03903699   8.65784596 ...,   7.47143258  -0.59421343
#      6.7210434 ]
#   [  5.47750804   0.79223311  -0.95001158 ...,  -2.22876981   4.79379397
#      6.87571768]]
#
#  [[ -4.30607744   4.71723214   1.2365223  ...,   4.93107967  10.01190673
#      1.74034008]
#   [  3.37692139   5.17822133   2.38031563 ...,  12.98509019   1.55305689
#     -1.4080347 ]]]

# %%
# run this cell
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# ## 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to. For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

# code here
# Plot 50 Gaussian distributions that each consists of 100 2-dimensional datapoints
pl.figure()
pl.subplot(111)
count = 0
for datapt in ReprRandAll:
    count += 1
    x = datapt[0][:]
    y = datapt[1][:]
    pl.plot(x, y, 'o', ms=3.5, label=(count))

pl.xlim(10 * np.min(ReprRandAll[:][0][:]), 10 * np.max(ReprRandAll[:][0][:]))
#pl.ylim(10 * np.min(ReprRandAll[:][0][:]), 10 * np.max(ReprRandAll[:][0][:]))
pl.suptitle('Figure 1:', fontsize=18, fontweight='bold', y=1.05)
pl.title('50 Gaussian Distributions-each w/ shape (2,100),seed:1-50',fontsize=15, y=1.02 )
pl.xlabel('X-axis', size=12) #rows of ReprRandAll that represent datapoint[0] for each datapoint)
pl.ylabel('Y-axis', size=12) #rows of ReprRandAll that represent datapoint[1] for each datapoint)
pl.legend(title='Legend: Marker-Districution#',fontsize=12, bbox_to_anchor=(1.05, 0.94),loc=2, ncol=5, borderaxespad=0. )

pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# ---If we keep seed unchanged----
# Generate 50 * (2,100) Gaussian distributions with unchanged seed(22) 
ReprRandAll2 = np.zeros((50, 2, 100))
np.random.seed(22)
for i in range(50):
    ReprRand = (1 + i*0.1) * np.random.randn(2,100) + i*0.1
    ReprRandAll2[i][:][:] = ReprRand

# %%
# plot figure 2 for the above distributions
pl.figure()
pl.subplot(111)
count = 0
for datapt in ReprRandAll2:
    count += 1
    x = datapt[0][:]
    y = datapt[1][:]
    pl.plot(x, y, 'o', ms= 3.5, label=(count))

pl.xlim(10 * np.min(ReprRandAll2[:][0][:]), 10 * np.max(ReprRandAll2[:][0][:]))
pl.ylim(10 * np.min(ReprRandAll2[:][0][:]), 10 * np.max(ReprRandAll2[:][0][:]))
pl.suptitle('Figure 2:', fontsize=18, fontweight='bold', y=1.05)
pl.title('50 Gaussian Distributions-each w/ shape (2,100),seed:22)',fontsize=15, y=1.02)
pl.xlabel('X-axis', size=12) #rows of ReprRandAll2 that represent datapoint[0] for each datapoint)
pl.ylabel('Y-axis', size=12) #rows of ReprRandAll2 that represent datapoint[1] for each datapoint)
pl.legend(title='Legend: Marker-Districution#',fontsize=12, bbox_to_anchor=(1.05, 0.94),loc=2, ncol=5, borderaxespad=0. )

pl.show()

# %% [markdown]
# Always add a caption to each of your homework figures.
# And remember to give your labels some names!
# This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.
#
# ## Figure 1:
#
# [write a caption here]

# %% [markdown]
# ## Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
# Method: Create a (50,100) array RR_y to store and shuffle the distributions along Y-axis
# and then use index to place those values into the variable ReprRandAll3
# Seed changing from 1-50
ReprRandAll3 = np.zeros((50, 2, 100))
RR_y = np.zeros((50, 100))
for i in range(50):
    np.random.seed(i+1)
    ReprRand = (1 + i*0.1) * np.random.randn(2,100) + i*0.1
    ReprRandAll3[i][0][:] = ReprRand[0][:]
    RR_y[i][:] = ReprRand[1][:]
    
np.random.shuffle(RR_y)

ind_g = np.arange(0,50, dtype=int)  # index pointing groups 0 to 49
ind_r = np.ones((1,50), dtype=int)  # index pointing row[1] within each group 

#print (ind_g, ind_r)

ReprRandAll3[ind_g, ind_r, :] = RR_y
print (ReprRandAll3)  #new ReprRandAll3 with row[1] shuffled among the 50 groups
# Out:
# [[[  1.62434536e+00  -6.11756414e-01  -5.28171752e-01 ...,   4.35968568e-02
#     -6.20000844e-01   6.98032034e-01]
#   [ -3.47402225e+00   4.99782938e+00   3.91406670e+00 ...,   1.15067101e+00
#      5.38809281e+00   5.26989032e+00]]
#
#  [[ -3.58433632e-01   3.81064901e-02  -2.24981571e+00 ...,  -1.38848796e-01
#      1.39088465e+00  -2.47796351e+00]
#   [  1.25109210e+01   8.79502860e-01   8.96049226e+00 ...,   1.88164123e+00
#      4.64954840e-03   7.65991757e+00]]
#
#  [[  2.34635417e+00   7.23811821e-01   3.15796962e-01 ...,  -8.26524602e-01
#     -1.60247289e-01   2.78977921e+00]
#   [  5.47750804e+00   7.92233111e-01  -9.50011577e-01 ...,  -2.22876981e+00
#      4.79379397e+00   6.87571768e+00]]
#
#  ...,
#  [[ -9.63698524e-01  -1.36138459e+00   1.06296728e+00 ...,  -5.92755007e+00
#      3.23337951e+00   8.07776860e+00]
#   [  6.74146901e+00   9.57118028e-02   3.97392287e+00 ...,   6.57160845e+00
#      3.18296403e+00  -3.23434276e-01]]
#
#  [[ -1.25032265e+00   3.90369910e-02   8.65784596e+00 ...,   7.47143258e+00
#     -5.94213427e-01   6.72104340e+00]
#   [ -9.13733479e-01   6.85792262e+00   9.82399479e+00 ...,   6.65470735e+00
#      3.35390782e+00   2.18510990e+00]]
#
#  [[ -4.30607744e+00   4.71723214e+00   1.23652230e+00 ...,   4.93107967e+00
#      1.00119067e+01   1.74034008e+00]
#   [ -7.83183987e-01   1.19899256e+00   1.22647311e+00 ...,   1.61826057e+00
#      2.10216283e+00   8.35305381e-01]]]

# %%
# plot figure 3 for the above generated distributions
pl.figure()
pl.subplot(111)
count = 0
for datapt in ReprRandAll3:
    count += 1
    x = datapt[0][:]
    y = datapt[1][:]
    pl.plot(x, y, 'o', ms= 3.5, label=(count))

pl.xlim(10 * np.min(ReprRandAll2[:][0][:]), 10 * np.max(ReprRandAll2[:][0][:]))
pl.ylim(10 * np.min(ReprRandAll2[:][0][:]), 10 * np.max(ReprRandAll2[:][0][:]))
pl.suptitle('Figure 3:', fontsize=18, fontweight='bold', y=1.05)
pl.title('50 Gaussian Distributions-each (2,100) distrubution has diff. mean and std)',fontsize=15, y=1.02)
pl.xlabel('X', size=12) #rows of ReprRandAll2 that represent datapoint[0] for each datapoint)
pl.ylabel('Y', size=12) #rows of ReprRandAll2 that represent datapoint[1] for each datapoint)
pl.legend(title='Legend: Marker-Districution#',fontsize=12, bbox_to_anchor=(1.05, 0.94),loc=2, ncol=5, borderaxespad=0. )

pl.show()
